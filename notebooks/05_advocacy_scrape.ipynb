# %% [markdown]
# # Advocacy Organization Scrape
# **Data Source:** Patient Advocacy (LE&RN / NLN)
#
# **Output:** Lymphedema support group and provider directories
#
# **DuckDB Table:** `advocacy_groups`

# %% [markdown]
# ## Setup

# %%
import pandas as pd
import duckdb
import requests
import sys
import os

sys.path.append('../src')
from config import *
from db import get_connection
from utils import *

# %% [markdown]
# ## Step 1 — Data Collection
# Scrape provider directories and support groups from LE&RN and NLN.

# %% [markdown]
# ## Step 2 — Cleaning

# %% [markdown]
# ## Step 3 — Load to DuckDB
