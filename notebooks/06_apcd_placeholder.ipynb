# %% [markdown]
# # APCD Processing Placeholder
# **Data Source:** APCD (All-Payer Claims Databases)
#
# **Output:** State-level all-payer claims
#
# **DuckDB Table:** `apcd_claims`

# %% [markdown]
# ## APCD Data Use Agreement (DUA) Links
# APCD requires a state Data Use Agreement. Links to apply:
# - MA: https://www.chiamass.gov/apcd/
# - CO: https://civhc.org/get-data/
# - OR: https://www.oregon.gov/oha/HPA/ANALYTICS/Pages/All-Payer-All-Claims.aspx

# %% [markdown]
# ## Setup

# %%
import pandas as pd
import duckdb
import requests
import sys
import os

sys.path.append('../src')
from config import *
from db import get_connection
from utils import *

# %% [markdown]
# ## Step 1 — Data Collection
# Process state-level all-payer claims (requires active DUA).

# %% [markdown]
# ## Step 2 — Cleaning

# %% [markdown]
# ## Step 3 — Load to DuckDB
